# %%
import pandas as pd

df = pd.read_csv("file_name", sep="\t") # Downloaded the dataset but the file was too large to push, provided a placeholder file_name for now
num_records = len(df)

print(num_records)
